# %% [markdown]
# <a href="https://colab.research.google.com/github/alinalatifah/KKA-X-Semester-1/blob/main/1_fungsi_print_Alina_X_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Alina Nurul Latifah
#
# Kelas : X - 11
#
# No Absen : 04

# %% [markdown]
# Menampilkan teks bebas

# %%
print("Halo world!")
# Out:
# Halo world!

# %%
nama_saudara = " muhammad faris farkhan"

print(nama_saudara)
# Out:
#  muhammad faris farkhan

# %%
jumlah_saudara = 2

print(jumlah_saudara)
# Out:
# 2

# %% [markdown]
# Menampilkan teks bebas dan nilai variabel

# %%
print("saya mempunyai saudara sebanyak")
# Out:
# saya mempunyai saudara sebanyak

# %%
print("Nama : Alina Nurul latifah")
print("kelas: X.11")
print("No.Absen: 04")
# Out:
# Nama : Alina Nurul latifah
# kelas: X.11
# No.Absen: 04

# %%
print("Nama: Alina Nurul Latifah\nkelas: X.11\nNo.Absen: 04")
# Out:
# Nama: Alina Nurul Latifah
# kelas: X.11
# No.Absen: 04

# %%
print("""Nama\t\t: Alina Nurul latifah
Kelas\t\t:X.11
No.Absen\t:04""")
# Out:
# Nama		: Alina Nurul latifah
# Kelas		:X.11
# No.Absen	:04

# %%
print("Alina Nurul Latifah")
# Out:
# Alina Nurul Latifah

# %%
print('Alina Nurul Latifah')
# Out:
# Alina Nurul Latifah

# %%
print('Habib')

# %%
nama_siswa_1 = "Daffanes"
nama_siswa_2 = "Adzka"
nama_siswa_3 = "Haidar"
print(nama_siswa_1, nama_siswa_2, sep="-")
# Out:
# Daffanes-Adzka

# %%
print(nama_siswa_3, nama_siswa_2, nama_siswa_1,nama_siswa_2,sep= "*")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3496104202.py in <cell line: 0>()
# ----> 1 print(nama_siswa_3, nama_siswa_2, nama_siswa_1,nama_siswa_2,sep= "*")
#
# NameError: name 'nama_siswa_3' is not defined

# %%
print(nama_siswa_1)
print(nama_siswa_2)
# Out:
# Daffanes
# Adzka

# %%
print(nama_siswa_1,nama_siswa_2)
# Out:
# Daffanes Adzka

# %%
print(nama_siswa_1,end="_")
print(nama_siswa_2)
# Out:
# Daffanes_Adzka

# %%
# Latihan soal
# Gunakan parameter end untuk menampilkan tulisan sebagai berikut:
# Haidar#Adzka#Daffanes#Adzka

# %%
print(nama_siswa_3,end="_")
print(nama_siswa_2,end="_")
print(nama_siswa_1,end="_")
print(nama_siswa_2)
# Out:
# Haidar_Adzka_Daffanes_Adzka
