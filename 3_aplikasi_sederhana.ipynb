# %% [markdown]
# <a href="https://colab.research.google.com/github/alinalatifah/KKA-X-Semester-1/blob/main/3_aplikasi_sederhana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Nama = Alina Nurul Latifah

Kelas = X.11

No.absen = 04

Nama kelompok =

# %% [markdown]
# Aplikasi Sederhana Menghitung Volume Bola

# %%
jari_jari = int(input("Masukkan jari_jari dari bola (cm): "))
pi = 22/7
volume_bola = 4/3 * pi * jari_jari**3
print(f"Volume bola adalah {volume_bola} cm^3. ")
# Out:
# Masukkan jari_jari dari bola (cm): 7
# Volume bola adalah 1437.333333333333 cm^3.

# %%
jari_jari = int(input("masukkan jari_jari dari kerucut(cm): "))
pi = 22/7
tinggi = 7
volume_kerucut = 1/3 * pi * jari_jari**2 *tinggi
print(f"volume kerucut adalah {volume_kerucut} cm^2. ")
# Out:
# masukkan jari_jari dari kerucut(cm): 14
# volume kerucut adalah 1437.3333333333333 cm^2.
